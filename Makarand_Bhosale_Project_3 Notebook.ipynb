# %% [markdown]
# # <center> Disney Studio Income Analysis

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/disney_movies.csv")

# %%
df.head(5)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  release_year
# 0    184925485                5228953251          1937
# 1     84300000                2188229052          1940
# 2     83320000                2187090808          1940
# 3     65000000                1078510579          1946
# 4     85000000                 920608730          1950

# %% [markdown]
# ## Task 1: Data Exploration

# %% [markdown]
# Checking Null Values , release_date into datatime , best & worst total gross
#
# > **Indented block**

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
df['release_date']=pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    datetime64[ns]
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 27.3+ KB

# %%
print("Worst total gross is : ",df['total_gross'].min())
print("Best total gross is :",df['total_gross'].max())
# Out:
# Worst total gross is :  0
# Best total gross is : 936662225

# %% [markdown]
# ## Task 2: Visualize Year Distribution Plot
#
# 1.   List item
#
# > Indented block
#
#
# 2.   List item

# %%
df['release_year']=df['release_date'].dt.year

# %%
df['release_year']
# Out:
# 0      1937
# 1      1940
# 2      1940
# 3      1946
# 4      1950
#        ...
# 574    2016
# 575    2016
# 576    2016
# 577    2016
# 578    2016
# Name: release_year, Length: 579, dtype: int64

# %%
df['release_year'].unique()
# Out:
# array([1937, 1940, 1946, 1950, 1954, 1955, 1959, 1961, 1962, 1963, 1967,
#        1968, 1970, 1971, 1975, 1977, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
df.columns
# Out:
# Index(['movie_title', 'release_date', 'genre', 'mpaa_rating', 'total_gross',
#        'inflation_adjusted_gross', 'release_year'],
#       dtype='object')

# %%
plt.bar(df['release_year'],df['total_gross'])
# Out:
# <BarContainer object of 579 artists>

# %% [markdown]
# ## Task 3: Does Movies Income Decreased or Increased?

# %%
plt.bar(df['release_year'],df['inflation_adjusted_gross'])
# Out:
# <BarContainer object of 579 artists>

# %%
#from the above graph we can clearly state that movies income decreased.

# %% [markdown]
# ## Task 4: Describe the total counts of Genres
#
# 1.   List item
#
# 1.   List item
#
# *   List item
# *   List item
#
#
# 2.   List item
#
#
# 2.   List item

# %%
#df['genre'].value_counts()

# %%
#df['genre'].count()

# %%
print("Total Genre Count is : ",len(df['genre'].unique()))
# Out:
# Total Genre Count is :  13
